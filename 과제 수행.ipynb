# %% [markdown]
# # 고객의 자동차 재구매 경향 분석
# * '대차'와 '추가구매'로 분류
# * '구매이력'과 '차량 보유정보' 등을 활용해 재구매 유형별 구매 시점 예측

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 과제 1

# %% [markdown]
# ## 01. '대차'와 '추가구매' 분리/추정
# 로직 개발

# %%
cars = pd.read_csv("/content/drive/MyDrive/해카톤/'21년 해카톤_데이터/'21년 해카톤_차량정보.csv", encoding='cp949')
cars.head()
# Out:
#                   CAR_ID            CUS_ID  ...    CAR_ENG_NM  CAR_TRIM_NM
# 0  H1308052741CBFA022907  AOZZZZO010000035  ...  가솔린 2.0 CVVL        SMART
# 1  H1308050341LBEA656859  AOZZZZO010000067  ...       LPG 2.0      PREMIUM
# 2  H1308052741DBFA038433  AOZZZZO010000190  ...       LPi 2.0      PREMIUM
# 3  H13080607413BFA007670  AOZZZZO010000371  ...         하이브리드      PREMIUM
# 4  H1308052741DBFA091812  AOZZZZO010000492  ...       LPi 2.0      PREMIUM
#
# [5 rows x 10 columns]

# %%
cars1 = cars[['CAR_ID','CUS_ID','WHOT_DT','CAR_HLDG_FNH_DT','CAR_NM']]
cars1.head()
# Out:
#                   CAR_ID            CUS_ID   WHOT_DT  CAR_HLDG_FNH_DT CAR_NM
# 0  H1308052741CBFA022907  AOZZZZO010000035  20140627       20170831.0  LF쏘나타
# 1  H1308050341LBEA656859  AOZZZZO010000067  20140711              NaN  YF쏘나타
# 2  H1308052741DBFA038433  AOZZZZO010000190  20140707              NaN  LF쏘나타
# 3  H13080607413BFA007670  AOZZZZO010000371  20140711              NaN  그랜저HG
# 4  H1308052741DBFA091812  AOZZZZO010000492  20150120              NaN  LF쏘나타

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1835830 entries, 0 to 1835829
# Data columns (total 5 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   CAR_ID           object
#  1   CUS_ID           object
#  2   WHOT_DT          int64
#  3   CAR_HLDG_FNH_DT  float64
#  4   CAR_NM           object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 70.0+ MB

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 날짜 데이터 타입 변경(-> str -> datetime)
cars1['WHOT_DT'] = cars1['WHOT_DT'].astype('str')
cars1['WHOT_DT'] = pd.to_datetime(cars1['WHOT_DT'])

# cars1['CAR_HLDG_STRT_DT'] = cars1['CAR_HLDG_STRT_DT'].astype('str')
# cars1['CAR_HLDG_STRT_DT'] = pd.to_datetime(cars1['CAR_HLDG_STRT_DT'])

# float64 타입에다가 NaN 값까지 가지고 있는 컬럼 처리
cars1['CAR_HLDG_FNH_DT'][cars1['CAR_HLDG_FNH_DT'].isnull()] = '20211231' # 임의로 먼 미래의 날짜로 지정하려했지만, pandas에서 사용 불가 오류로 이번 해 마지막 날짜로 지정
cars1['CAR_HLDG_FNH_DT'] = cars1['CAR_HLDG_FNH_DT'].astype('int')
cars1['CAR_HLDG_FNH_DT'] = cars1['CAR_HLDG_FNH_DT'].astype('str')
cars1['CAR_HLDG_FNH_DT'] = pd.to_datetime(cars1['CAR_HLDG_FNH_DT'])

# %%
# 차량ID, 고객ID, 출고일자, 보유종료일자, 차명
cars2 = cars1.sort_values(['CUS_ID', 'WHOT_DT', 'CAR_HLDG_FNH_DT'], ignore_index=True)
cars2
# Out:
#                         CAR_ID            CUS_ID  ... CAR_HLDG_FNH_DT CAR_NM
# 0        H1308031441VP6U069690  AONEEOO010000113  ...      2007-07-12    베르나
# 1        H1308060741EBBA077034  AONEEOO010000113  ...      2021-12-31  그랜저HG
# 2        H1308052141BP5A053834  AONEEOO020000165  ...      2021-12-31    쏘나타
# 3        H1308070241ABAU090781  AONEEOO020000165  ...      2021-12-31   제네시스
# 4        H1308190381PP1U052991  AONEEOO020000170  ...      2011-06-08    싼타페
# ...                        ...               ...  ...             ...    ...
# 1835825  H1308051441BP2A665825  ATZZZZV310001228  ...      2004-11-09    쏘나타
# 1835826  H1308030751BPYU060804  ATZZZZV310001232  ...      2008-04-12    베르나
# 1835827  H1308040741LBCU575856  ATZZZZV310001232  ...      2014-12-06  아반떼MD
# 1835828  H1308051441SPYA320981  ATZZZZV310001236  ...      2004-02-04    쏘나타
# 1835829  H1308060841NBBA056058  ATZZZZV310001236  ...      2011-11-09  그랜저HG
#
# [1835830 rows x 5 columns]

# %% [markdown]
# ### '대차'와 '추가구매'
#
# * 대차: *기존 보유하던 차량을 처분하고, 신차를 출고하는 경우*
# * 추가구매: *기존 보유하던 차량을 처분하지 않고, 추가로 신차를 출고하는 경우*

# %% [markdown]
# ### 분리 기준
# * 신차구매 = 출고날짜 기준
# * 처분 시점 = 보유 종료 일자 기준
# * 첫 번째 구매 차량은 '첫구매'로 가정
# * **기존 보유 차량의 처분 시점 전후 3개월 내 신차 구매를 '대차'로 가정**
# * **대차의 경우 제외 후, 기존 보유 차량 이외로 추가 신차 구매를 '추가구매'로 가정**

# %%
cars2['CUS_ID'].value_counts(sort=True, dropna=True)
# Out:
# ATZZTZT260000436    12
# AONNHZF030000491    12
# ATZZVZE050001085    12
# ATZZTZH040001065    12
# ATZZFZN210000948    12
#                     ..
# ATZOFOZ130001259     1
# ATZZSZE160001760     1
# ATZZZZT180000816     1
# ATZZPZE180000337     1
# ATZOVZO130000438     1
# Name: CUS_ID, Length: 1096206, dtype: int64

# %%
cars2[cars2['CUS_ID']=='AONNHZF030000491'] # 여러 대의 차를 한꺼번에 소유하면서 거래를 한 경우도 존재
# Out:
#                       CAR_ID            CUS_ID  ... CAR_HLDG_FNH_DT  CAR_NM
# 25113  H1308190481VP1U100413  AONNHZF030000491  ...      2007-07-19     싼타페
# 25114  H1308030741FP2U369354  AONNHZF030000491  ...      2007-03-16     베르나
# 25115  H1308030741FP2U389421  AONNHZF030000491  ...      2021-12-31     베르나
# 25116  H1308030741FP2U432002  AONNHZF030000491  ...      2004-05-12     베르나
# 25117  H1308190481VP4U738510  AONNHZF030000491  ...      2007-03-06     싼타페
# 25118  H1308042141BP7U148283  AONNHZF030000491  ...      2009-12-04     아반떼
# 25119  H1308022151DP7U723866  AONNHZF030000491  ...      2009-12-08      클릭
# 25120  H1308192381UBDU169069  AONNHZF030000491  ...      2017-08-17  싼타페 DM
# 25121  H1308040741DBFU360270  AONNHZF030000491  ...      2021-12-31   아반떼MD
# 25122  H1308042741DBHU278824  AONNHZF030000491  ...      2021-12-31   아반떼AD
# 25123  H1308042741DBHU284998  AONNHZF030000491  ...      2021-12-31   아반떼AD
# 25124  H1308192381UBJU802108  AONNHZF030000491  ...      2021-12-31  싼타페 DM
#
# [12 rows x 5 columns]

# %%
# 차량 구매 특징을 구분할 새로운 컬럼 생성 'TYPE'
cars2['TYPE'] = '미정'

# 현재까지 소유한 차량 '소유'로 표기
# cars2['TYPE'][cars2['CAR_HLDG_FNH_DT']=='2021-12-31'] = '소유'

# %%
cars2.head()
# Out:
#                   CAR_ID            CUS_ID  ... CAR_NM TYPE
# 0  H1308031441VP6U069690  AONEEOO010000113  ...    베르나   미정
# 1  H1308060741EBBA077034  AONEEOO010000113  ...  그랜저HG   미정
# 2  H1308052141BP5A053834  AONEEOO020000165  ...    쏘나타   미정
# 3  H1308070241ABAU090781  AONEEOO020000165  ...   제네시스   미정
# 4  H1308190381PP1U052991  AONEEOO020000170  ...    싼타페   미정
#
# [5 rows x 6 columns]

# %%
# 일부 데이터 먼저 활용
cars3 = cars2[:300]

# %%
cars3.head()
# Out:
#                   CAR_ID            CUS_ID  ... CAR_NM TYPE
# 0  H1308031441VP6U069690  AONEEOO010000113  ...    베르나   미정
# 1  H1308060741EBBA077034  AONEEOO010000113  ...  그랜저HG   미정
# 2  H1308052141BP5A053834  AONEEOO020000165  ...    쏘나타   미정
# 3  H1308070241ABAU090781  AONEEOO020000165  ...   제네시스   미정
# 4  H1308190381PP1U052991  AONEEOO020000170  ...    싼타페   미정
#
# [5 rows x 6 columns]

# %%
# 회원별로 데이터프레임을 만들어서 처리 후 다시 합치기
df = []

for customer in cars3['CUS_ID'].unique():
  temp = cars3[cars3['CUS_ID']==customer]
  temp.reset_index(inplace=True, drop=True)
  temp.sort_values(by='WHOT_DT', ascending=False)

  # 첫 번째 구매 차량 '첫구매'로 표기
  temp['TYPE'][0] = '첫구매'

  for start in range(1,len(temp)):
    for end in range(len(temp)):
      # 3개월 이내에 기존 차량 처분 후 새차량 구매한 경우
      if start > end:
        if (temp['CAR_HLDG_FNH_DT'][end] - temp['WHOT_DT'][start]).days > 0:
          temp['TYPE'][start] = '추가구매'
      if start != end:
        if 0 < (temp['CAR_HLDG_FNH_DT'][end] - temp['WHOT_DT'][start]).days < 90:
          temp['TYPE'][start] = '대차'
      
  df.append(temp)


df = pd.concat(df)
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# * '미정'은 기존 보유 차량 처분 후 3개월 이상 차량을 미소지한 후 새차량을 구매한 경우

# %%
df.head(40)
# Out:
#                    CAR_ID            CUS_ID  ...  CAR_NM  TYPE
# 0   H1308031441VP6U069690  AONEEOO010000113  ...     베르나   첫구매
# 1   H1308060741EBBA077034  AONEEOO010000113  ...   그랜저HG    미정
# 2   H1308052141BP5A053834  AONEEOO020000165  ...     쏘나타   첫구매
# 3   H1308070241ABAU090781  AONEEOO020000165  ...    제네시스  추가구매
# 4   H1308190381PP1U052991  AONEEOO020000170  ...     싼타페   첫구매
# 5   H1308192381UBDU081735  AONEEOO020000170  ...  싼타페 DM    미정
# 6   H1308191081UBBU647205  AONEEOO020000290  ...     싼타페   첫구매
# 7   H1308192381UBJU777377  AONEEOO020000290  ...  싼타페 DM    미정
# 8   H1308190881WP6U064927  AONEEOO040000233  ...     싼타페   첫구매
# 9   H1308042141BBAU837494  AONEEOO040000233  ...     아반떼  추가구매
# 10  H1308051441BPYA282823  AONEEOO040000329  ...     쏘나타   첫구매
# 11  H1308042041BP7U177233  AONEEOO040000329  ...     아반떼    미정
# 12  H1308131081VP6U278548  AONEEOO040000408  ...     트라제   첫구매
# 13  H1308060141BP9A344364  AONEEOO040000408  ...     그랜저    미정
# 14  H1308030751BPYU061320  AONEEOO050000235  ...     베르나   첫구매
# 15  H1308051441MP3U015080  AONEEOO050000251  ...     쏘나타   첫구매
# 16  H1308050341BBAA152068  AONEEOO050000328  ...   YF쏘나타   첫구매
# 17  H1308142181WP8U082020  AONEEOO050000363  ...   베라크루즈   첫구매
# 18  H1308042141BBAU977314  AONEEOO050000363  ...     아반떼  추가구매
# 19  H1308192381UBGU618951  AONEEOO050000363  ...  싼타페 DM  추가구매
# 20  H1308052741CBJA398390  AONEEOO050000363  ...   LF쏘나타  추가구매
# 21  H1308062241CP1A151658  AONEEOO050000367  ...     그랜저   첫구매
# 22  H1308030741GP2U346875  AONEEOO050000367  ...     베르나  추가구매
# 23  H1308072041CP3U051046  AONEEOO050000367  ...  VI 에쿠스  추가구매
# 24  H1308052141BP6A182066  AONEEOO050000367  ...     쏘나타  추가구매
# 25  H1308030741GP1U268932  AONEEOO050000406  ...     베르나   첫구매
# 26  H1308060141BP8A266545  AONEEOO050000406  ...     그랜저    미정
# 27  H1308060741EBBA001805  AONEEOO050000406  ...   그랜저HG    미정
# 28  H1308192381UBDU160055  AONEEOO070000157  ...  싼타페 DM   첫구매
# 29  H1308042141BP7U250206  AONEEOO070000194  ...     아반떼   첫구매
# 30  H1308102181VBAU076074  AONEEOO070000194  ...    투싼ix  추가구매
# 31  H1308040741DBEU864371  AONEEOO070000194  ...   아반떼MD  추가구매
# 32  H1308190481VP2U397811  AONEEOO070000256  ...     싼타페   첫구매
# 33  H1308050341BBCA410127  AONEEOO070000256  ...   YF쏘나타  추가구매
# 34  H1308102181VBAU082428  AONEEOO070000324  ...    투싼ix   첫구매
# 35  H1308060741EBCA182727  AONEEOO070000324  ...   그랜저HG    대차
# 36  H1308192381UBJU809368  AONEEOO070000324  ...  싼타페 DM    대차
# 37  H13080502415BCA042027  AONEEOO080000258  ...   YF쏘나타   첫구매
# 38  H1308040741DBDU785153  AONEEOO080000258  ...   아반떼MD  추가구매
# 39  H1308191081UBAU568159  AONEEOO080000315  ...     싼타페   첫구매
#
# [40 rows x 6 columns]

# %%
# 전체 데이터 대입

# 회원별로 데이터프레임을 만들어서 처리 후 다시 합치기
df2 = []

for customer in cars2['CUS_ID'].unique():
  temp = cars2[cars2['CUS_ID']==customer]
  temp.reset_index(inplace=True, drop=True)
  temp.sort_values(by='WHOT_DT', ascending=False)

  # 첫 번째 구매 차량 '첫구매'로 표기
  temp['TYPE'][0] = '첫구매'

  for start in range(1,len(temp)):
    for end in range(len(temp)):
      # 3개월 이내에 기존 차량 처분 후 새차량 구매한 경우
      if start > end:
        if (temp['CAR_HLDG_FNH_DT'][end] - temp['WHOT_DT'][start]).days > 0:
          temp['TYPE'][start] = '추가구매'
      if start != end:
        if 0 < (temp['CAR_HLDG_FNH_DT'][end] - temp['WHOT_DT'][start]).days < 90:
          temp['TYPE'][start] = '대차'
      
  df2.append(temp)


df2 = pd.concat(df2)
df2.reset_index(inplace=True, drop=True)

# %%
df2.head(30)

# %%
df2.to_excel('./재구매유형 추가 데이터.xlsx')

# %% [markdown]
# ## 02. EDA
# 고객과 차량 관점에서 특징과 차이점 도출
